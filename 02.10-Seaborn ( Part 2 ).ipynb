# %% [markdown]
# # Seaborn : ( Part 2 )
# # In this part we will use seaborn to visualize many plots and we will take out conclusion from that plots which is very  important in EDA.

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/kasm/Downloads/train.csv',index_col=0)
df1=df._get_numeric_data()
nc=list(df1.columns)
df2=df.drop(columns=nc)
cc=list(df2.columns)
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
df1.shape
# Out:
# (1460, 37)

# %%
df2.shape
# Out:
# (1460, 43)

# %%
df1.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %%
df2.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %% [markdown]
# # 1

# %%
sns.distplot(df['MSSubClass'])

# %%
df['MSSubClass'].describe()
# Out:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
sorted(list(df['MSSubClass'].unique()))
# Out:
# [20, 30, 40, 45, 50, 60, 70, 75, 80, 85, 90, 120, 160, 180, 190]

# %%
df['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
# We can conclude from this graph that
# mssubclass is high at 20
# major data is concentrated between 20 to 80 subclass
# more info is collecte from describe
# sice count is equal to col ther is no missing value
# we can remove mssubsclass from 120 to 190 as an outlier or 160 to 190 confirm

# %% [markdown]
# # 2

# %%
sns.distplot(df['SalePrice'],rug=True,)

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df['SalePrice'].value_counts()
# Out:
# 140000    20
# 135000    17
# 145000    14
# 155000    14
# 190000    13
# 110000    13
# 160000    12
# 115000    12
# 139000    11
# 130000    11
# 125000    10
# 143000    10
# 185000    10
# 180000    10
# 144000    10
# 175000     9
# 147000     9
# 100000     9
# 127000     9
# 165000     8
# 176000     8
# 170000     8
# 129000     8
# 230000     8
# 250000     8
# 200000     8
# 141000     8
# 215000     8
# 148000     7
# 173000     7
#           ..
# 64500      1
# 326000     1
# 277500     1
# 259000     1
# 254900     1
# 131400     1
# 181134     1
# 142953     1
# 245350     1
# 121600     1
# 337500     1
# 228950     1
# 274000     1
# 317000     1
# 154500     1
# 52000      1
# 107400     1
# 218000     1
# 104000     1
# 68500      1
# 94000      1
# 466500     1
# 410000     1
# 437154     1
# 219210     1
# 84900      1
# 424870     1
# 415298     1
# 62383      1
# 34900      1
# Name: SalePrice, Length: 663, dtype: int64

# %%
# conclude
# min sale price is 34900
# max is 755000 
# average is 163000
# maximum house are available at rs 80000 to 280000
# house price of 300000 to 400000 is not available more or min is average
# high rate house is minimum
# sice count is equal to col heace all house saleprice data is collected
# there is no outlier since all are imp
# more imfo can collected fro describe above

# Hence ther is more range of options to those who are looking for 80000 to 280000rs house

# %% [markdown]
# # 3

# %%
sns.distplot(df['PoolArea'])

# %%
df['PoolArea'].describe()
# Out:
# count    1460.000000
# mean        2.758904
# std        40.177307
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       738.000000
# Name: PoolArea, dtype: float64

# %%
sorted(list(df['PoolArea'].unique()))
# Out:
# [0, 480, 512, 519, 555, 576, 648, 738]

# %%
df['PoolArea'].value_counts()
# Out:
# 0      1453
# 738       1
# 648       1
# 576       1
# 555       1
# 519       1
# 512       1
# 480       1
# Name: PoolArea, dtype: int64

# %%
df[df['PoolArea']==738]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1424         Lvl    AllPub   CulDSac  ...      738     Gd  GdPrv         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1424       0      8    2006        WD         Alloca     274970
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==648]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 811          20       RL         78.0    10140   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                   ...
# 811         Lvl    AllPub    Inside  ...      648     Fa  GdPrv         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 811       0      1    2006        WD         Normal     181000
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==576]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1171          80       RL         76.0     9880   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1171         Lvl    AllPub    Inside  ...      576     Gd  GdPrv         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1171       0      7    2008        WD         Normal     171000
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==555]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1183         Lvl    AllPub    Corner  ...      555     Ex  MnPrv         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1183       0      7    2007        WD        Abnorml     745000
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==519]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1387          60       RL         80.0    16692   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1387         Lvl    AllPub    Inside  ...      519     Fa  MnPrv        TenC
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1387    2000      7    2006        WD         Normal     250000
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==512]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 198          75       RL        174.0    25419   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                   ...
# 198         Lvl    AllPub    Corner  ...      512     Ex  GdPrv         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 198       0      3    2006        WD        Abnorml     235000
#
# [1 rows x 80 columns]

# %%
df[df['PoolArea']==480]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...      480     Gd   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1299       0      1    2008       New        Partial     160000
#
# [1 rows x 80 columns]

# %%
# Conclude
# Aailable pool areas are 0,480,512,519,555,576,648,738
# as seen in count almost all pool area is 0 only one house of remaining area is available..
# the one available area off all imformation is above...

# %% [markdown]
# # 4

# %%
df1.head(3)
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# Id                                                    ...
# 1           2003       196.0         706           0  ...           0
# 2           1976         0.0         978           0  ...         298
# 3           2002       162.0         486           0  ...           0
#
#     OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# Id
# 1            61              0          0            0         0        0
# 2             0              0          0            0         0        0
# 3            42              0          0            0         0        0
#
# ...

# %%
sns.distplot(df['YearBuilt'])

# %%
df['YearBuilt'].value_counts()
# Out:
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
# 1976    33
# 1977    32
# 1920    30
# 1959    26
# 1999    25
# 1998    25
# 1958    24
# 1965    24
# 1970    24
# 1954    24
# 2000    24
# 2002    23
# 2008    23
# 1972    23
# 1968    22
# 1971    22
# 1950    20
# 2001    20
# 1957    20
# 1962    19
# 1994    19
# 1966    18
# 2009    18
# 1995    18
# 1940    18
#         ..
# 1986     5
# 1952     5
# 1880     4
# 1929     4
# 1932     4
# 1938     4
# 1983     4
# 1927     3
# 1919     3
# 1934     3
# 1989     3
# 1987     3
# 1912     3
# 1885     2
# 1892     2
# 1890     2
# 1942     2
# 1908     2
# 1882     1
# 1875     1
# 1893     1
# 2010     1
# 1898     1
# 1904     1
# 1905     1
# 1906     1
# 1911     1
# 1913     1
# 1917     1
# 1872     1
# Name: YearBuilt, Length: 112, dtype: int64

# %%
df['YearBuilt'].describe()
# Out:
# count    1460.000000
# mean     1971.267808
# std        30.202904
# min      1872.000000
# 25%      1954.000000
# 50%      1973.000000
# 75%      2000.000000
# max      2010.000000
# Name: YearBuilt, dtype: float64

# %%
# Conclude
# oldest house is built on 1872
# new one on 2010
# max house is built from 1920 to 2010
# we have all data of this no NaN

# %% [markdown]
# # 5

# %%
df1.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# Id                                                    ...
# 1           2003       196.0         706           0  ...           0
# 2           1976         0.0         978           0  ...         298
# 3           2002       162.0         486           0  ...           0
# 4           1970         0.0         216           0  ...           0
# 5           2000       350.0         655           0  ...         192
#
# ...

# %%
sns.distplot(df['YrSold'])

# %%
df['YrSold'].value_counts()
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: YrSold, dtype: int64

# %%
df['YrSold'].describe()
# Out:
# count    1460.000000
# mean     2007.815753
# std         1.328095
# min      2006.000000
# 25%      2007.000000
# 50%      2008.000000
# 75%      2009.000000
# max      2010.000000
# Name: YrSold, dtype: float64

# %%
# Conclude
# max house was sold on 2009 338 houses where sold then in 2007 329 then in 2006 then 2008 then in 2010
# in last record means inn 2010 low number where sold bcz max houses wher alread sold in 2009

# %% [markdown]
# # 6

# %%
sns.boxplot(df['GarageCars'])

# %%
df['GarageCars'].describe()
# Out:
# count    1460.000000
# mean        1.767123
# std         0.747315
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: GarageCars, dtype: float64

# %%
df['GarageCars'].value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
# Conclution
# capacity of car storage in garage is know as garagecars
# number of houses with garagecars 1,2 are max but 2garagecars are maximum
# number of houses with garagecars  0,3 are average
# low number of houses with garagecars 4 but cant conclude as outlier

# %% [markdown]
# # 7

# %%
sns.boxplot(df['OverallQual'])

# %%
df['OverallQual'].describe()
# Out:
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %%
df['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
# Conclution
# cheap quality houses i.e 1,2,3,4 is very less only 141houses
# high quality houses i.e 8,9,10 is 229
# all other medium quality houses i.e 5,6,7 have max number of houses i.e 1090
# quality 1,2 is only 5houses

# %% [markdown]
# # 8

# %%
sns.boxplot(df['Fireplaces'])

# %%
df['Fireplaces'].describe()
# Out:
# count    1460.000000
# mean        0.613014
# std         0.644666
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: Fireplaces, dtype: float64

# %%
df['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
df1[df1['Fireplaces']==3]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 167           20          NaN    10708            5            5       1955
# 310           20         90.0    12378            9            5       2003
# 606           60         85.0    13600            7            6       1965
# 643           80         75.0    13860            8            7       1972
# 1299          60        313.0    63887           10            5       2008
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# Id                                                      ...
# 167           1993         0.0         379         768  ...         476
# 310           2004         0.0        1274           0  ...         208
# 606           1990       176.0         454           0  ...           0
# 643           1995         0.0        1410           0  ...         269
# 1299          2008       796.0        5644           0  ...         214
#
# ...

# %%
# Conclution
# all this are ckear b looking describe

# %% [markdown]
# # 9

# %%
sns.boxplot(df['LotArea'])

# %%
df['LotArea'].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
df['LotArea'].value_counts()
# Out:
# 7200     25
# 9600     24
# 6000     17
# 10800    14
# 9000     14
# 8400     14
# 1680     10
# 7500      9
# 8125      8
# 9100      8
# 6120      8
# 6240      8
# 3182      7
# 7800      6
# 8450      6
# 10000     5
# 4500      5
# 4435      5
# 5000      5
# 10140     5
# 9750      5
# 10400     5
# 5400      5
# 7018      4
# 11700     4
# 9375      4
# 8800      4
# 9900      4
# 8750      4
# 6600      4
#          ..
# 3136      1
# 13418     1
# 10448     1
# 8849      1
# 7313      1
# 11425     1
# 13472     1
# 8029      1
# 11952     1
# 9738      1
# 12936     1
# 5271      1
# 11414     1
# 12122     1
# 9364      1
# 7314      1
# 9360      1
# 16226     1
# 11404     1
# 15498     1
# 9353      1
# 11400     1
# 14175     1
# 7301      1
# 11394     1
# 7094      1
# 6130      1
# 9337      1
# 5232      1
# 8190      1
# Name: LotArea, Length: 1073, dtype: int64

# %%
# Conclusion
# no NaN value
# max area available is 215245
# min area available is 1300

# %% [markdown]
# # 10

# %%
nc[4]
# Out:
# 'OverallCond'

# %%
sns.countplot(df['OverallCond'])

# %%
df['OverallCond'].describe()
# Out:
# count    1460.000000
# mean        5.575342
# std         1.112799
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         6.000000
# max         9.000000
# Name: OverallCond, dtype: float64

# %%
# Conclusion
# count is high at 5 so averge codition house availibity is high i.e approx 800 hoouses
# poor condition houses are very less
# few number ofhouses are avalaible with excellent quality

# %% [markdown]
# # 11

# %%
df['ScreenPorch'].describe()
# Out:
# count    1460.000000
# mean       15.060959
# std        55.757415
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       480.000000
# Name: ScreenPorch, dtype: float64

# %%
sns.countplot(df['ScreenPorch'],)

# %%
df["ScreenPorch"].value_counts()
# Out:
# 0      1344
# 192       6
# 224       5
# 120       5
# 189       4
# 180       4
# 160       3
# 168       3
# 144       3
# 126       3
# 147       3
# 90        3
# 200       2
# 198       2
# 216       2
# 184       2
# 259       2
# 100       2
# 176       2
# 170       2
# 288       2
# 142       2
# 153       1
# 154       1
# 152       1
# 155       1
# 145       1
# 156       1
# 143       1
# 322       1
#        ...
# 163       1
# 165       1
# 291       1
# 287       1
# 276       1
# 273       1
# 271       1
# 266       1
# 265       1
# 263       1
# 260       1
# 252       1
# 234       1
# 233       1
# 225       1
# 374       1
# 222       1
# 220       1
# 210       1
# 204       1
# 197       1
# 385       1
# 190       1
# 396       1
# 185       1
# 182       1
# 440       1
# 178       1
# 312       1
# 480       1
# Name: ScreenPorch, Length: 76, dtype: int64

# %%
# Conclusion
# no porch is provided to max houses
# how much is provided toother some houses is listed above

# %% [markdown]
# # 12

# %%
sns.countplot(df['HalfBath'])

# %%
df['HalfBath'].value_counts()
# Out:
# 0    913
# 1    535
# 2     12
# Name: HalfBath, dtype: int64

# %%
df.loc[df['HalfBath']==2,['HalfBath','SalesPrice']]     #Doubt
# Out:
#       HalfBath  SalesPrice
# Id
# 189          2         NaN
# 299          2         NaN
# 598          2         NaN
# 625          2         NaN
# 629          2         NaN
# 922          2         NaN
# 1155         2         NaN
# 1164         2         NaN
# 1231         2         NaN
# 1284         2         NaN
# 1351         2         NaN
# 1451         2         NaN

# %%
# Conclusion
# max house are not providing powder room i.e halfbath
# 535 house are proiding one powder room
# onl 12 house has 2 powder room

# %% [markdown]
# # 13

# %%
sns.countplot(df['Fireplaces'])

# %%
# Conclusion
# approx 690 houses dnont have fireplaces
# approx 650 houses have onl one fireplaces
# aprox 100 have two fireplaces and approx 10 has 2 fp
# max house sold was with no fp and 1 fp

# %% [markdown]
# # 14

# %%
sns.countplot(df['FullBath'])

# %%
# Colclution
# max house sold which have 1 to 2 fullbath

# %% [markdown]
# # 15 (Multivariate)

# %%
sns.lmplot('SalePrice','OverallQual',data=df,fit_reg=False)

# %%
# Conclusion
# best is 
# if our budget aprox 50k to 60k go with 5star
# if our budget is 90k to 100k o with 7star but onl one house vailable if not get go with 6sstar
# if our budget is more than 100k ou should go with 10,9,8 star housesbest is here 10star but accordingl

# %% [markdown]
# # 16

# %%
nc[-2:]
# Out:
# ['YrSold', 'SalePrice']

# %%
sns.lmplot('YrSold','SalePrice',data=df)

# %%
sorted(df['YrSold'].unique())
# Out:
# [2006, 2007, 2008, 2009, 2010]

# %%
# Coclusion
# highest value for house we get on 2007
# almost same number of houses is sold in ever Year but with slow dicrement

# %% [markdown]
# # 17

# %%
sns.lmplot('OverallCond','SalePrice',data=df)

# %%
# Conclusion
# dont go with qualit 1,2,3 ether go with 4,5,6 with same price good condition
# if our budget is between 90k to 100k we can get 7,8 conditio wala but better go with 8
# if our budget is above 100k then the best is available that is 9 condition wala go with that onl

# %% [markdown]
# # 18

# %%
sns.lmplot('YearBuilt','SalePrice',data=df)

# %%
# Coclusion
# maximum houses where built between 1910 to 2010
# the saleprice was boobing at high rate for more houses in 2000 to 2010
# increase in ear leads to increse in price
# outliers can be seen in graph

# %% [markdown]
# # 19

# %%
sns.lmplot('SalePrice','LotArea',data=df,height=6)

# %%
# Conclusion
# saleprce ranges from 25k to approx 470k for approx 20k area for max houses
# price increase as area increase overall
# outlierscan be seen

# %% [markdown]
# # 20

# %%
sns.jointplot('YearBuilt','SalePrice',data=df,kind='reg')

# %%
# Conclson
# outliers can be seen
# commented alread before

# %% [markdown]
# # 21

# %%
sns.jointplot('LotArea','SalePrice',data=df)

# %%
# Conclusion
# Major houses have 25k lotarea in variet  of prices 
# outliers ca be seen

# %% [markdown]
# # 22

# %%
sns.jointplot('LotFrontage','LotArea',data=df)

# %%
df.loc[df['LotArea']==1300,['LotArea','LotFrontage']]
# Out:
#      LotArea  LotFrontage
# Id
# 957     1300         24.0

# %%
# Conclusion
# max houses sold where within 25k area within 150 lotfrontage
# outlieirs can be seen

# %% [markdown]
# # 23

# %%
df['PoolArea'].describe()
# Out:
# count    1460.000000
# mean        2.758904
# std        40.177307
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       738.000000
# Name: PoolArea, dtype: float64

# %%
sns.jointplot('PoolArea','OverallQual',data=df)

# %%
# Conclusion
# Pololarea is not provided to maximum house almost all
# outliers can be seen

# %% [markdown]
# # 24

# %%
sns.jointplot('GarageArea','GarageCars',data=df,kind='reg')

# %%
# Conclusion
# Gragearea is not used full b owners thier are ver empt space left in garage

# %% [markdown]
# # 25

# %%
a=nc[0:3]
sns.pairplot(df[a])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conclusion:
# same columns leads to hist and different wala leads to lmplot

# %% [markdown]
# # 26

# %%
sns.pairplot(df[nc[-3:]])

# %%
# Conclusion:
# same columns leads to hist and different wala leads to lmplot
# price vs mosold shows tht the demand of purchasing house of a customer is almost same in all mounths but n mounth 7 good price getted
# also in all ear good amount of house where sold but in 2019 is was best

# %% [markdown]
# # 27

# %%
sns.pairplot(df[['PoolArea','GrLivArea','BedroomAbvGr','KitchenAbvGr','GarageArea','SalePrice']],kind='reg')

# %%
# Connclusion
# max house sale was without poolarea
# customer are giving garagearea more importance then pool
# more importance to grlivarea then pool
# as grlivarea iscease the saleprice icreases
# people selecting garagearea and grlivarea according to him but majorit ranges 0 to 1.5kgragearea for 0 to 2.9k grlivarea 
# 1 kitchen is chosen for grlivarea between 0 t  3.75k sometimes 2 kichen is choosen for 5to2.5k grlivarea
# as garagarea increases saaleprice also increase
# kitchen above ground if 1 the house is given more importance b customer ad more house is also sell some peopletaken 2kichen wala but low price
# most available garage area is betwee 0 to 1k
# outliers can be seen

# %% [markdown]
# # 28

# %%
sns.heatmap(df.iloc[:,0:8].corr(),vmin=-1,cmap='viridis')

# %%
# here highest corr is between lotfrontage vs lotarea between 0.4

# %% [markdown]
# # 29

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df1.iloc[:,8:18].corr(),cmap='viridis',annot=True)

# %%
# corr is high at 1stflrsf vs totalbsmtsf remove one
# also high at bsmthalfbath vs bsmfinsf1
# also at grlivearea vs 2ndflrsf

# %% [markdown]
# # 29

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.iloc[:,-20:].corr(),cmap='viridis',linewidth=0.01,annot=True)

# %%
# corr is high at garagearea vs garagecars remove one
# also high at price vs garagecars 
# also at price vs garage area
# but b this three sitution car or area should removed not price

# %% [markdown]
# # 30

# %%
plt.figure(figsize=(30,12))
sns.heatmap(df.corr(),cmap='viridis',annot=True)

# %% [markdown]
# # 31

# %%
plt.figure(figsize=(6,15))
sns.heatmap(df.corr()[["SalePrice"]].sort_values(by=["SalePrice"],ascending=False),cmap='viridis',annot=True,linewidths=0.1)

# %%
# saleprice is not high corr but with overallqual....

# %% [markdown]
# # 32

# %%
plt.figure(figsize=(6,15))
sns.heatmap(df.corr()[["SalePrice","MSSubClass"]].sort_values(by=["SalePrice","MSSubClass"],ascending=False),cmap='viridis',annot=True,linewidths=0.1)

# %%
# saleprice wala alrea commented
# less corr between mssubclass and others

# %% [markdown]
# # 33

# %%
a=pd.crosstab(index=df[cc[0]],columns=df[cc[2]])
a.plot(kind='bar',figsize=(12,8),stacked=True,colormap='Paired')

# %%
cc[2]
# Out:
# 'Alley'

# %%
df.loc[(df['Alley']=='Pave')&(df['MSZoning']=='RL')]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 329           75       RL          NaN    11888   Pave  Pave      IR1
# 362           50       RL          NaN     9144   Pave  Pave      Reg
# 381           50       RL         50.0     5000   Pave  Pave      Reg
# 498           50       RL         60.0     9120   Pave  Pave      Reg
# 1264          70       RL         60.0    13515   Pave  Pave      Reg
# 1415          50       RL         64.0    13053   Pave  Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 329          Bnk    AllPub    Inside  ...        0    NaN    NaN         NaN
# 362          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 381          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 498          Lvl    AllPub    Inside  ...        0    NaN  GdPrv         NaN
# ...

# %%
df.loc[(df['Alley']=='Grvl')&(df['MSZoning']=='RL')]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 93            30       RL         80.0    13360   Pave  Grvl      IR1
# 292          190       RL         55.0     5687   Pave  Grvl      Reg
# 391           50       RL         50.0     8405   Pave  Grvl      Reg
# 440           50       RL         67.0    12354   Pave  Grvl      Reg
# 521          190       RL         60.0    10800   Pave  Grvl      Reg
# 621           30       RL         45.0     8248   Pave  Grvl      Reg
# 815           50       RL         45.0     8248   Pave  Grvl      Reg
# 1077          50       RL         60.0    10800   Pave  Grvl      Reg
# 1184          30       RL         60.0    10800   Pave  Grvl      Reg
# 1378          50       RL         60.0    10998   Pave  Grvl      Reg
# 1381          30       RL         45.0     8212   Pave  Grvl      Reg
# 1405          50       RL         60.0    10410   Pave  Grvl      Reg
# ...

# %%
# things are cleared b looking graph and above step...

# %% [markdown]
# # 34

# %%
a=pd.crosstab(index=df[cc[10]],columns=df[cc[18]])
a.plot(kind='barh',figsize=(12,9),stacked=True,colormap='Paired')

# %%
# things are cleared looking graph

# %%
# Remaining plots do as Homework practice....Happy Learning...:)

# End...
