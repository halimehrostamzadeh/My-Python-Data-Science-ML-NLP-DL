# %% [markdown]
# # This contains important Syntax & Topics which we have studied till now:

# %%
# Strings
# Topics : 
# Syntax , Assingning strings to variables , Indexing , .strip(' ') , len() , .lower() , .upper() ,
# .replace(" ","") , Adding of strings


# List
# Represents by Square brackets []
# ordered, changeble, allows duplicate members.
# Topics :
# syntax , Indexing , len() , 
# .append() , .extend() , .insert() , .remove() , .reverse()
# addition of list , list(range( , ))
# List comprehension.
# some extra : .pop() , .sort() , .clear() , .copy() , .count() , .index()


# Tuples
# Represents by round brackets ()
# Ordered, Unchangable 
# Topics:
# Syntax , Indexing , len() , set()
# Some extra: .count() , .index()


# Sets:
# Represents by curly brackets {}
# Unordered, Indexing not possible
# Topics:
# .add() , .update() , .discard() , set()
# & - Gives intersection of two sets
# - - Returns the first set values which is not present in other set
# many more not imp.


# Dictionaries:
# Represents by curly brackets {}
# Unordered, changeble, indexed
# Topics:
# Get the value, Change the value, Number of items, Adding items, Reoving items, Remove the last item, Empty the dict, Indexing.
# many ore not imp.


# Numpy
# It is an python library which is used for array list to array
# Topics:
# 1D : np.array() , type() , .size , .shape , np.ndim() , sum() 
# 2D : same as in 1D , .reshape( , ) 
# np.arange( , ) , np.zeros(( , )) , np.ones(( , )) , np.eye() , np.linspace( , , ) ,
# np.random.rand( , ) , np.random.randn( , ) , np.random.randint( , , ) , np.random.randint( , ,size=( , )) , 
# Operators, Filtering, ravel()
# Assignment: np.setdiff1d( , ) , np.intersect1d( , ) , np.union1d( . ) , np.randon.uniform( , ,size=( , )) , .tolist() , swapping
# changing value using filtering, indexing, etc.


# Pandas:
# Topics: Using Array and Dictionaries....
# df=pd.Dataframe() , type() , .dtypes , .size , .shape , .index , .columns , .info() , .head(n) , .tail(n)
# df[].unique , df[].unique() , df[].unique().reshape( , ) , df[].nunique() , df[].value_counts()  
# df=pd.DataFrame( ,index=[....],columns=[....]
# df[''].unique , df[''].unique() , df[''].unique().reshape() , df[''].nunique() , df[''].value_counts()  
# .index=[.......]   (to change the index)
# .columns=[......]   (to change the columns)
# .rename(columns={'':''},index={'':''},inplace=True)  (inplace use to overwrite)
# Indexing: df[''] or df. , df[['','']] , df.iloc[ , ] , df.iloc[:,[ , , ]] , df.loc['',''] , 
# df.loc[df[''] > _ , ['','']] or df.loc[df.a > _ , ['','']]   ...( filtering and indexing)
# .drop(labels=['',...],axis=1,inplace=True) or .drop(columns=['','',...])
# .drop(index=[''])
# pd.Series()  ...for list, dict, array it changes to seris columns.
# dict(zip( , )) ,
# Filtering: df[df['']==''] , df[(df['']=='') & (df['']=='')]
# adding series to dataframe in col: df['']=df1
# .sort_values() , .sort_values('') , .sort_values('',ascending=False) , .set_index('') , .reset_index('')
# Pivot table...
# pd.concat([ , ]) , pd.concat([ , ],axis=1)  
# .join( ,how='outer') , .join( ,how='inner') , .join( ,how='left') , .join( ,how='right') ....(col names should be different)
# pd.merge( , ,how=' ',on=[''..]) ....(atleast one col name should be same)


# Matplotlib:
# Bar , Plot , Histogram , Scatter , Subplots


# EDA using seaborn:
# Topics:
# Univariate:
# Numeric - distplot , boxplot
# Category - countplot
# Multivariate:
# Num vs Num - lmplot , jointplot , pairplot ,heatmap
# cat vs cat - crosstabplot
# cat vs num - boxplot , swarmplot , violinplot

# Sytax:
# df=pd.read_csv('C:/Users/kasm/Downloads/train.csv',index_col=0) ... #index_col=0  ....1,2,3 is the col
# Apply basic pandas
# df1=df._get_numeric_data()
# nc=list(df1.columns)
# df2=df.drop(columns=nc)
# cc=list(df2.columns)
# a=set(df)  b=set(df1)  c=a-b  cc1=list(c)
# sns.distplot(df[nc[0]])
# sns.distplot(df[nc[0]],kde=False)
# sns.boxplot(df[nc[0]])
# sns.countplot(df[cc[0]])
# sns.countplot(y=df[cc[0]])
# sns.lmplot(nc[0],nc[1],data=df,fit_reg=True)
# sns.lmplot(nc[0],nc[1],data=df,fit_reg=False)
# sns.jointplot(nc[0],nc[1],data=df,kind='reg')
# sns.jointplot(nc[0],nc[1],data=df,kind='hex')
# cols=[nc[0],nc[1],nc[3]]   sns.pairplot(df[cols])
# sns.heatmap(df.corr(),cmap='viridis')
# crosstab=pd.crosstab(index=df["Neighborhood"],columns=df['OverallQual'])
# ==>crosstab.plot(kind='bar',figsize=(12,8),stacked=True,colormap='Paired')
# sns.boxplot(cc[0],nc[1],data=df)
# sns.swarmplot(cc[0],nc[1],data=df)
# sns.violinplot(cc[0],nc[1],data=df)

# %% [markdown]
# # ...END...
